# %%
# train sequential deep learning model with tabular data: https://towardsdatascience.com/deeplearning-with-tabular-data-data-processing-cd2e73908257

import pandas as pd
#lab_data_path = "../datasets/csv-data/Lab_Verisi_01012023_26072023.xlsx"
process_5min_path = "../datasets/csv-data/ProsesVerisi_5dakikalık.csv"
process_15min_path = "../datasets/csv-data/ProsesVerisi_15dakikalık.csv"

process_5min = pd.read_csv(process_5min_path, sep=";")
process_15min = pd.read_csv(process_15min_path, sep=";")

# %%
process_5min.head()
# Out:
#         Unnamed: 0                                 HGO HOT     REFLUX  \
# 0        TimeStamp  Root.P-1.U1100.Flow.AFC903.PV.Value - Time Ave...
# 1        1.01.2022                                        96,42365374
# 2  1.01.2022 00:05                                        94,61052256
# 3  1.01.2022 00:10                                         95,6172522
# 4  1.01.2022 00:15                                        96,03237498
#
#                                HV.GAS OIL  TO C_1102  \
# 0  Root.P-1.U1100.Temp.ATI505.PV.Value - Time Ave...
# 1                                        287,5280143
# 2                                        287,6063249
# 3                                        287,9191012
# 4                                        287,8344999
#
#                                LT.GAS OIL  TO C_1102  \
# 0  Root.P-1.U1100.Temp.ATI504.PV.Value - Time Ave...
# 1                                        243,3322943
# 2                                        243,3700798
# ...
